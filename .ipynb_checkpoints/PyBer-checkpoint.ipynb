# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics

# %%
city_data_df=pd.read_csv("Resources/city_data.csv")
ride_data_df=pd.read_csv("Resources/ride_data.csv")

# %%
city_data_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
ride_data_df.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344

# %%
city_data_df.count()
# Out:
# city            120
# driver_count    120
# type            120
# dtype: int64

# %%
ride_data_df.count()
# Out:
# city       2375
# date       2375
# fare       2375
# ride_id    2375
# dtype: int64

# %%
ride_data_df.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id      int64
# dtype: object

# %%
city_data_df.dtypes
# Out:
# city            object
# driver_count     int64
# type            object
# dtype: object

# %%
city_data_df["type"].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
sum(city_data_df["type"]=="Urban")
# Out:
# 66

# %%
sum(city_data_df["type"]=="Suburban")
# Out:
# 36

# %%
sum(city_data_df["type"]=="Rural")
# Out:
# 18

# %%
city_ride_df=pd.merge(city_data_df,ride_data_df, on=["city","city"])

# %%
city_ride_df.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2019-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2019-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2019-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2019-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2019-04-17 02:26:37  23.00   720020655850

# %%
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
urban_cities_df = pyber_data_df[pyber_data_df["type"] == "Urban"]
urban_cities_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
Suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]
Rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]

# %%
urban_ride_count=urban_cities_df.groupby(["city"]).count()["ride_id"]
Suburban_ride_count=Suburban_cities_df.groupby(["city"]).count()["ride_id"]
Rural_ride_count=Rural_cities_df.groupby(["city"]).count()["ride_id"]

# %%
urban_avg_fare = urban_cities_df.groupby(["city"]).mean()["fare"]
suburban_avg_fare = Suburban_cities_df.groupby(["city"]).mean()["fare"]
rural_avg_fare = Rural_cities_df.groupby(["city"]).mean()["fare"]

# %%
urban_driver_count = urban_cities_df.groupby(["city"]).mean()["driver_count"]
suburban_driver_count = Suburban_cities_df.groupby(["city"]).mean()["driver_count"]
rural_driver_count = Rural_cities_df.groupby(["city"]).mean()["driver_count"]

# %%
plt.scatter(urban_ride_count,
      urban_avg_fare,
      s=10*urban_driver_count, c="coral",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Urban")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
# Add the legend.
plt.legend()

# %%
plt.scatter(Suburban_ride_count,
      suburban_avg_fare,
      s=10*suburban_driver_count, c="skyblue",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Suburban")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
# Add the legend.
plt.legend()

# %%
plt.scatter(Rural_ride_count,
      rural_avg_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
# Add the legend.
plt.legend()

# %%
plt.subplots(figsize=(10, 6))
plt.scatter(urban_ride_count,
      urban_avg_fare,
      s=10*urban_driver_count, c="coral",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Urban")

plt.scatter(Suburban_ride_count,
      suburban_avg_fare,
      s=10*suburban_driver_count, c="skyblue",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Suburban")

plt.scatter(Rural_ride_count,
      rural_avg_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")

plt.title("PyBer Ride-Sharing Data (2019)", fontsize=20)
plt.ylabel("Average Fare ($)", fontsize=12)
plt.xlabel("Total Number of Rides (Per City)", fontsize=12)
plt.grid(True)

# Add the legend.
lgnd = plt.legend(fontsize="12", mode="Expanded",
         scatterpoints=1, loc="best", title="City Types")
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]
lgnd.get_title().set_fontsize(12)
plt.text(42, 35, "Note: Circle size correlates with driver count per city.", fontsize="12")
plt.savefig("analysis/Fig1.png")

# %%
urban_cities_df.describe()
# Out:
#               fare       ride_id  driver_count
# count  1625.000000  1.625000e+03   1625.000000
# mean     24.525772  4.873485e+12     36.678154
# std      11.738649  2.907440e+12     20.075545
# min       4.050000  1.458810e+10      3.000000
# 25%      14.550000  2.400244e+12     22.000000
# 50%      24.640000  4.711188e+12     37.000000
# 75%      34.580000  7.451579e+12     52.000000
# max      44.970000  9.991538e+12     73.000000

# %%
Suburban_cities_df.describe()

Rural_ride_count.describe()
# Out:
# count    18.000000
# mean      6.944444
# std       2.508157
# min       3.000000
# 25%       5.250000
# 50%       6.000000
# 75%       8.750000
# max      12.000000
# Name: ride_id, dtype: float64

# %%
Rural_cities_df.describe()
# Out:
#              fare       ride_id  driver_count
# count  125.000000  1.250000e+02    125.000000
# mean    34.623440  4.647746e+12      4.296000
# std     14.558046  2.887834e+12      2.691156
# min     10.110000  2.684873e+10      1.000000
# 25%     19.900000  2.275364e+12      1.000000
# 50%     37.050000  4.023962e+12      4.000000
# 75%     47.070000  7.118047e+12      7.000000
# max     58.550000  9.990581e+12      9.000000

# %%
round(urban_ride_count.mean(),2), round(Suburban_ride_count.mean(),2), round(Rural_ride_count.mean(),2)
# Out:
# (24.62, 17.36, 6.94)

# %%
urban_ride_count.median()
# Out:
# 24.0

# %%
urban_ride_count.mode()
# Out:
# 0    22
# 1    25
# dtype: int64

# %%
Suburban_ride_count.mode()
# Out:
# 0    17
# dtype: int64

# %%
import scipy.stats as sts

# %%
mean_urban_ride_count = np.mean(urban_ride_count)
print(f"The mean for the ride counts for urban trips is {mean_urban_ride_count:.2f}.")

median_urban_ride_count = np.median(urban_ride_count)
print(f"The median for the ride counts for urban trips is {median_urban_ride_count}.")

mode_urban_ride_count = sts.mode(urban_ride_count)
print(f"The mode for the ride counts for urban trips is {mode_urban_ride_count}.")
# Out:
# The mean for the ride counts for urban trips is 24.62.
# The median for the ride counts for urban trips is 24.0.
# The mode for the ride counts for urban trips is ModeResult(mode=array([22], dtype=int64), count=array([7])).

# %%
mode_ride=sts.mode(Rural_ride_count)
mode_suburban_ride
print(f" the mode is {mode_ride}")
# Out:
#  the mode is ModeResult(mode=array([6], dtype=int64), count=array([5]))

# %%
mean_urban_fares=np.mean(urban_cities_df["fare"])
print(f"The mean fare price for urban trips is ${mean_urban_fares:.2f}.")
median_urban_fares =np.median(urban_cities_df["fare"])
print(f"The median fare price for urban trips is ${median_urban_fares:.2f}.")

mode_urban_fares = sts.mode(urban_cities_df["fare"])
print(f"The mode fare price for urban trips is {mode_urban_fares}.")
# Out:
# The mean fare price for urban trips is $24.53.
# The median fare price for urban trips is $24.64.
# The mode fare price for urban trips is ModeResult(mode=array([22.86]), count=array([5])).

# %%
mean_Suburban__fares=np.mean(Suburban_cities_df["fare"])
print(f"The mean fare price for Suburban trips is ${mean_Suburban__fares:.2f}.")
median_Suburban__fares =np.median(Suburban_cities_df["fare"])
print(f"The median fare price for Suburban trips is ${median_Suburban__fares:.2f}.")

mode_Suburban__fares = sts.mode(Suburban_cities_df["fare"])
print(f"The mode fare price for Suburban trips is {mode_Suburban__fares}.")
# Out:
# The mean fare price for Suburban trips is $30.97.
# The median fare price for Suburban trips is $30.75.
# The mode fare price for Suburbann trips is ModeResult(mode=array([17.99]), count=array([3])).

# %%
mean_Rural_fares=np.mean(Rural_cities_df["fare"])
print(f"The mean fare price for Rural trips is ${mean_Rural_fares:.2f}.")
median_Rural_fares =np.median(Rural_cities_df["fare"])
print(f"The median fare price for Rural trips is ${median_Rural_fares:.2f}.")

mode_Rural_fares = sts.mode(Rural_cities_df["fare"])
print(f"The mode fare price for Rural trips is {mode_Rural_fares}.")
# Out:
# The mean fare price for Rural trips is $34.62.
# The median fare price for Rural trips is $37.05.
# The mode fare price for Rural trips is ModeResult(mode=array([37.05]), count=array([2])).

# %%
mean_urban_driver_count=np.mean(urban_cities_df["driver_count"])
print(f"The mean driver_count  for urban trips is {mean_urban_driver_count:.2f}.")
median_urban_driver_count =np.median(urban_cities_df["fare"])
print(f"The median driver_count for urban trips is {median_urban_driver_count:.2f}.")

mode_urban_driver_count = sts.mode(urban_cities_df["fare"])
print(f"The mode driver_count  for urban trips is {mode_urban_driver_count}.")
# Out:
# The mean driver_count  for urban trips is 36.68.
# The median driver_count for urban trips is 24.64.
# The mode driver_count  for urban trips is ModeResult(mode=array([22.86]), count=array([5])).

# %%
mean_Suburban__driver_count =np.mean(Suburban_cities_df["driver_count"])
print(f"The mean driver_count  for Suburban trips is {mean_Suburban__driver_count:.2f}.")
median_Suburban__driver_count =np.median(Suburban_cities_df["driver_count"])
print(f"The median driver_count   for Suburban trips is {median_Suburban__driver_count:.2f}.")

mode_Suburban__driver_count  = sts.mode(Suburban_cities_df["driver_count"])
print(f"The mode driver_count   for Suburban trips is {mode_Suburban__driver_count}.")
# Out:
# The mean driver_count  for Suburban trips is 13.71.
# The median driver_count   for Suburban trips is 16.00.
# The mode driver_count   for Suburban trips is ModeResult(mode=array([20], dtype=int64), count=array([79])).

# %%
mean_Rural__driver_count =np.mean(Rural_cities_df["driver_count"])
print(f"The mean driver_count  for Rural trips is {mean_Rural__driver_count:.2f}.")
median_Rural__driver_count =np.median(Rural_cities_df["driver_count"])
print(f"The median driver_count  for Rural trips is {median_Rural__driver_count:.2f}.")

mode_Rural__driver_count  = sts.mode(Rural_cities_df["driver_count"])
print(f"The mode driver_count   for Rural trips is {mode_Rural__driver_count}.")
# Out:
# The mean driver_count  for Rural trips is 4.30.
# The median driver_count  for Rural trips is 4.00.
# The mode driver_count   for Rural trips is ModeResult(mode=array([1], dtype=int64), count=array([32])).

# %%
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_ride_count, labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Ride Count Data (2019)')
ax.set_ylabel('Number of Rides')
ax.set_yticks(np.arange(10, 41, step=2.0))
ax.grid()
plt.show()

# %%
x_labels = ["Urban", "Suburban","Rural"]
ride_count_data = [urban_ride_count, Suburban_ride_count, Rural_ride_count]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Ride Count Data (2019)',fontsize=20)
ax.set_ylabel('Number of Rides',fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_count_data, labels=x_labels)
ax.set_yticks(np.arange(0, 45, step=3.0))
ax.grid()
plt.savefig("analysis/Fig2.png")
plt.show()

# %%
urban_ride_count
# Out:
# city
# Amandaburgh            18
# Barajasview            22
# Carriemouth            27
# Christopherfurt        27
# Deanville              19
#                        ..
# West Patrickchester    16
# West Robert            31
# West Samuelburgh       25
# Williamsstad           23
# Williamsview           20
# Name: ride_id, Length: 66, dtype: int64

# %%
urban_city_outliner=urban_ride_count[urban_ride_count==39]

# %%
urban_city_outliner
# Out:
# city
# West Angela    39
# Name: ride_id, dtype: int64

# %%
urban_city_outliner=urban_ride_count[urban_ride_count==39].index[0]
urban_city_outliner
# Out:
# 'West Angela'

# %%
x_labels = ["Urban","Suburban","Rural"]
ride_count_data = [urban_cities_df["fare"],Suburban_cities_df["fare"],Rural_cities_df["fare"]]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Ride Fare Count Data (2019)',fontsize=20)
ax.set_ylabel('Fare($USD)',fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_count_data, labels=x_labels)
ax.set_yticks(np.arange(0, 60, step=2.0))
ax.grid()
plt.savefig("analysis/Fig3.png")
plt.show()

# %%
x_labels = ["Urban","Suburban","Rural"]
ride_count_data = [urban_cities_df["driver_count"],Suburban_cities_df["driver_count"],Rural_cities_df["driver_count"]]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('driver_count Count Data (2019)',fontsize=20)
ax.set_ylabel('number of drivers',fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_count_data, labels=x_labels)
ax.set_yticks(np.arange(0, 80, step=5.0))
ax.grid()
#plt.savefig("analysis/Fig3.png")
#plt.show()

# %%
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
date1=pyber_data_df.groupby("type").sum()["fare"]
date1.index[0:3]
# Out:
# Index(['Rural', 'Suburban', 'Urban'], dtype='object', name='type')

# %%
import matplotlib as mpl

# %%
plt.subplots(figsize=(10, 6))
plt.pie(date1,
        labels=date1.index[0:3],
        colors=["gold", "lightskyblue", "lightcoral"],
        startangle=150,
        explode=[0,0,0.1],
        autopct="%1.2f%%",
        shadow=True)
plt.title("% of Total Fares by City Type")
mpl.rcParams['font.size'] = 14
# Save Figure
plt.savefig("analysis/Fig5.png")
# Show Figure
plt.show()

# %%
date2=pyber_data_df.groupby("type").count()["ride_id"]
labels2=date2.index[0:3]

# %%
date2
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
plt.subplots(figsize=(10, 6))
plt.pie(date2,
        labels=labels2,
        colors=["gold", "lightskyblue", "lightcoral"],
        startangle=150,
        explode=[0,0,0.1],
        autopct="%1.2f%%",
        shadow=True)
plt.title("% of Total rides by City Type")
mpl.rcParams['font.size'] = 14

# %%
date3=pyber_data_df.groupby("type").sum()["driver_count"]
labels3=date3.index[0:3]

# %%
plt.subplots(figsize=(10, 6))
plt.pie(date3,
        labels=labels3,
        colors=["gold", "lightskyblue", "lightcoral"],
        startangle=150,
        explode=[0,0,0.1],
        autopct="%1.2f%%",
        shadow=True)
plt.title("% of Total drivers by City Type")
mpl.rcParams['font.size'] = 14
